# %% [markdown]
# <a href="https://colab.research.google.com/github/owenfab/IDS/blob/main/HW1/fabulaIDS_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IDS Homework 1
# ##Owen Fabula

# %% [markdown]
# #Problem 1
# First, I created a bar graph that displayed the total weight of chickens as a result of consuming each type of feed. From this graph, it is clear that the sunflower feed resulted in the highest sum of chicken weight, and that the horsebean feed resulted in the lowest sum of chicken weight.
# ![sumWeights.PNG](data:image/png;base64,...)
#
# I then created a table that displays the minimum, maximum, and average values for the chicken weights that result from each kind of feed. From the table, one can see that the lowest minimum weight, 108, resulted from the horsebean feed, while the feed with the highest minimum weight was the sunflower feed with 226. The lowest average weight, 160.2, also came from the horsebean feed, while the highest average weight, 328.9, again resulted from the sunflower feed. Finally, the horsebean feed also yielded the smallest maximum weight with 227, and the sunflower seed once again provided the highest maximum weight with 423.
# ![chickWeightsGraph.PNG](data:image/png;base64,...)
#
# From these results, it is clear that the sunflower feed would be the most beneficial for a poultry business. Such a business would want to ensure that its chickens are as heavy as possible so that they may yield the greatest amount of sellable meat, and by each metric displayed above, the sunflower feed would serve that end the best. First, the sunflower feed produced the highest minimum value out of all the other feeds, meaning that even the smallest chickens on sunflower feed are still larger than the other feed selections. The sunflower feed also yielded the highest maximum weight value, meaning that its largest and heaviest chickens are larger and heavier than all other feed options. Finally, the sunflower feed produced the highest average weight, meaning that generally speaking, chickens fed with sunflower feed will be heavier than if they used another type of feed.

# %% [markdown]
# #Problem 2
# I first created a bar graph that displays the sum of all ratings for each insurance provider. From the graph, one can see that Progressive has the highest sum of ratings, while USAA has the lowest sum of ratings.
# ![image.png](data:image/png;base64,...)
#
# I then created a table that displays the minumum, maximum, and average ratings for each insurance provider. From the table, one can see that USAA has the lowest minimum rating with 3.8 out of 10, whereas Progressive has the highest minimum rating with 6.7 out of 10. The lowest average rating, 6.1, was held by USAA, while the highest average rating, 7.7, was held by Progressive. Finally, GEICO yielded the highest maximum rating with 9.2, and USAA held the lowest maximum rating, with 8.1.
# ![image.png](data:image/png;base64,...)
#
# From these results, I conclude that Progressive would be the best insurance provider to select. First, Progressive has the highest minimum rating, meaning that even its least satisfied customers are still more satisfied relative to the other insurance providers. Progressive also has the highest average rating, meaning that generally, its customers are happier with its services than customers of other providers. Finally, GEICO may have the highest maximum rating, meaning that its most satified customers were happier than the most satified Progressive customers, but I do not believe that this changes the decision to opt into Progressive. Despite GEICO's maximum, Progressive's min and average values show that its general customer base is more satisfied than that of GEICO, making it an overall safer bet.
